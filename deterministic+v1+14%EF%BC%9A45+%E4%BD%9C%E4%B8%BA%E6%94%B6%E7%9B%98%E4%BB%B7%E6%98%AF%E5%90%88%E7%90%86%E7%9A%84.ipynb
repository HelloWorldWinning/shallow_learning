# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
start_date='2016-06-13'
frequency='1m'

# %%
real_daily=get_price('510050.XSHG', start_date, end_date='2017-01-17', frequency='1d' )
# real_daily

# %%
from zplot import zplot,zplot_ud

# %%
zplot_ud(real_daily[['close','high','low']])
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~wtk72528/2.embed" height="525px" width="100%"></iframe>

# %%
zplot(real_daily[['close','open']])
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~wtk72528/2.embed" height="525px" width="100%"></iframe>

# %%
zplot(real_daily[['close','open']])
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~wtk72528/2.embed" height="525px" width="100%"></iframe>

# %%
import cufflinks as cf

# %%
real_daily[['close','open']].iplot(kind='scatter')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~wtk72528/165.embed" height="525px" width="100%"></iframe>

# %%
real_daily[['close','open']].iplot()
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~wtk72528/163.embed" height="525px" width="100%"></iframe>

# %%
pseudo_daliy=get_price('510050.XSHG', start_date, end_date='2017-01-18', frequency=frequency )
pseudo_daliy=pseudo_daliy.between_time('9:30','14:45')
# pseudo_daliy

# %%
p_low=pseudo_daliy['low'].groupby(pseudo_daliy.index.date).min()
p_high=pseudo_daliy['high'].groupby(pseudo_daliy.index.date).max()
p_close=pseudo_daliy['close'].groupby(pseudo_daliy.index.date).tail(1)

# %%
temp_close=pd.DataFrame(real_daily['close'])
temp_close.columns=['real_close']
temp_close['pseudo_close']=p_close.values
temp_close.plot()

# %%
x=temp_close
x['diff']=(x['real_close']- x['pseudo_close']) /x['real_close']

# %%
diff= x['diff']

# %%
diff.plot()

# %%
diff.plot.density()

# %%
diff.rolling(10).std().plot()

# %%
temp_high=pd.DataFrame(real_daily['high'])
temp_high.columns=['real_high']
temp_high['pseudo_high']=p_high.values
temp_high.plot()

# %%
temp_low=pd.DataFrame(real_daily['low'])
temp_low.columns=['real_low']
temp_low['pseudo_low']=p_low.values
temp_low.plot()
